# %% [markdown]
# # Practical_2: String and files

# %% [markdown]
# ---
#
# ### Exercise 1:
# Create a string variable `text` and assign it the value `"Python is amazing!"`.
#
# ```python
# # Exercise 1
# ```

# %%
text="Python is amazing!"
text
# Out:
# 'Python is amazing!'

# %% [markdown]
# ---
#
# ### Exercise 2:
# Find the length of the string `"Hello, World!"` and store it in a variable `length`.
#
# ```python
# # Exercise 2
# ```

# %%
length= len("Hello, World!")
length
# Out:
# 13

# %% [markdown]
# ---
#
# ### Exercise 3:
# Convert the string `"python programming"` to uppercase and store it in a variable `upper_text`.
#
# ```python
# # Exercise 3
# ```

# %%
upper_text= "python programming".upper()
upper_text
# Out:
# 'PYTHON PROGRAMMING'

# %% [markdown]
# ---
#
# ### Exercise 4:
# Extract the first 5 characters from the string `"Artificial Intelligence"`.
#
# ```python
# # Exercise 4
# ```

# %%
w="Artificial Intelligence"
w[:5]
# Out:
# 'Artif'

# %% [markdown]
# ---
#
# ### Exercise 5:
# Concatenate the strings `"Hello"` and `"World"` with a space in between.
#
# ```python
# # Exercise 5
# ```

# %%
m="Hello"+" "+"World"
m
# Out:
# 'Hello World'

# %% [markdown]
# ---
#
# ### Exercise 6:
# Replace the word `"dog"` with `"cat"` in the string `"The quick brown dog jumps over the lazy dog."`.
#
# ```python
# # Exercise 6
# ```

# %%
j="The quick brown dog jumps over the lazy dog."
new_j=j.replace("dog","cat")
new_j
# Out:
# 'The quick brown cat jumps over the lazy cat.'

# %% [markdown]
# ---
#
# ### Exercise 7:
# Split the string `"apple,banana,orange"` by commas and store the result in a list `fruits_list`.
#
# ```python
# # Exercise 7
# ```
#
# -

# %%
fruits_list="apple,banana,orange".split(",")

fruits_list
# Out:
# ['apple', 'banana', 'orange']

# %% [markdown]
# --
#
# ### Exercise 8:
# Use string formatting to create the sentence `"My name is Alice and I am 25 years old."`, where the name and age are variables.
#
# ```python
# # Exercise 8
# ```

# %%
name="Alice"
age=25
print("My name is {} and I am {} years old.".format(name,age))
# Out:
# My name is Alice and I am 25 years old.

# %% [markdown]
# ---
#
# ### Exercise 9:
# Check if the string `"python"` is present in the sentence `"I love python programming"`.
#
# ```python
# # Exercise 9
# ```

# %%
sentence= "I love python programming"
existence='python' in sentence
print(existence)
# Out:
# True

# %% [markdown]
# ---
#
# ### Exercise 10:
# Count the number of occurrences of the letter `"e"` in the string `"Elephant is an elegant animal"`.
#
# ```python
# # Exercise 10
# ```

# %%
text="Elephant is an elegant animal"
count_e= text.count('e')
count_e
# Out:
# 3

# %% [markdown]
# ---
#
# ### Exercise 11:
# Remove any leading and trailing spaces from the string `"   Data Science   "`.
#
# ```python
# # Exercise 11
# ```

# %%
texto="   Data Science   "
removeSpace=texto.strip()

removeSpace
# Out:
# 'Data Science'

# %% [markdown]
# ---
#
# ### Exercise 12:
# Convert the string `"100"` into an integer and store it in a variable `int_value`.
#
# ```python
# # Exercise 12
# ```

# %%
int_value=int("100")
int_value
# Out:
# 100

# %% [markdown]
# ---
#
# ### Exercise 13:
# Extract the substring `"pro"` from the string `"programming"`.
#
# ```python
# # Exercise 13
# ```

# %%
a="programming"
b=a[:3]
b
# Out:
# 'pro'

# %% [markdown]
# ---
#
# ### Exercise 14:
# Check if the string `"data"` starts with `"da"` and ends with `"ta"`.
#
# ```python
# # Exercise 14
# ```

# %%
text="data"
if text.startswith('da') and text.endswith('ta'):
    print(True)
else:
    print(False)
# Out:
# True

# %% [markdown]
# ---
#
# ### Exercise 15:
# Reverse the string `"machine learning"` and store the result in `reversed_text`.
#
# ```python
# # Exercise 15
# ```

# %%
text="machine learning"
reversed_text=text[::-1]
reversed_text
# Out:
# 'gninrael enihcam'

# %% [markdown]
# ---
#
# ### Exercise 16:
# Convert the first letter of each word in the string `"machine learning is fun"` to uppercase.
#
# ```python
# # Exercise 16
# ```

# %%
letter="machine learning is fun"
upper_word=letter.title()
upper_word
# Out:
# 'Machine Learning Is Fun'

# %% [markdown]
# ---
#
# ### Exercise 17:
# Create a multiline string representing a poem and store it in a variable `poem`.
#
# ```python
# # Exercise 17
# ```

# %%
poem = """The moonlight dances on the sea,
Whispering tales of mystery.
Stars above begin to gleam,
Guardians of each silent dream."""
print(poem)
# Out:
# The moonlight dances on the sea,
# Whispering tales of mystery.
# Stars above begin to gleam,
# Guardians of each silent dream.

# %% [markdown]
# ---
#
# ### Exercise 18:
# Write a string to a file named `"output.txt"`.
#
# ```python
# # Exercise 18
# ```

# %%
#define variabe text
text="I miss my home"
with open("output.txt","w") as file:
    file.write(text)
##affichage et lire
with open("output.txt", "r") as file:
    content = file.read()
    print(content)
# Out:
# I miss my home

# %% [markdown]
# ---
#
# ### Exercise 19:
# Read the contents of a file named `"data.txt"` and print it line by line.
#
# ```python
# # Exercise 19
# ```

# %%
# with open("data.txt", "w") as file:
   # Create and write to the file
with open("data.txt", "w") as file:
    file.write("Hello World\n")
    file.write("Welcome to AIMS SN\n")
    file.write("Nice to meet you all\n")

# Now read and print it line by line
with open("data.txt", "r") as file:
    for line in file:
        print(line.strip())
# Out:
# Hello World
# Welcome to AIMS SN
# Nice to meet you all

# %% [markdown]
# ---
#
# ### Exercise 20:
# Check if a file `"example.txt"` exists before opening it.
#
# ```python
# # Exercise 20
# ```

# %%
# Read entire file
file = open('example.txt', 'r')
content = file.read()
print(content)
file.close()
# Out:
# ﻿L'urgence climatique s'intensifie, forçant les gouvernements à revoir leurs stratégies d'adaptation. Les données récentes confirment que les événements météorologiques extrêmes, tels que les inondations dévastatrices et les vagues de chaleur record, ne sont plus des anomalies, mais la nouvelle norme. Face à cette réalité, la pression monte sur la communauté internationale pour dépasser les simples engagements de réduction des émissions. L'accent se déplace désormais sur le financement de la transition énergétique dans les pays en développement et sur la mise en place de mesures de résilience immédiates, allant de la construction d'infrastructures plus robustes à l'établissement de systèmes d'alerte précoce pour protéger les populations les plus vulnérables

# %% [markdown]
# ---
#
# ### Exercise 21:
# Append a new line `"This is a new line"` to an existing file `"notes.txt"`.
#
# ```python
# # Exercise 21
# ```

# %%
lines = []
f = open('example.txt','r')
for line in f:
    lines.append("This is a new line")
f.close()
print(lines)
# Out:
# ['This is a new line']

# %% [markdown]
# ---
#
# ### Exercise 22:
# Read the contents of a file `"log.txt"` and store each line in a list `log_lines`.
#
# ```python
# # Exercise 22
# ```

# %%
with open('log.txt', 'r') as file:
    
    log_lines = file.readlines()

# %%
print(log_lines)
# Out:
# ["Aux Etats-Unis, dans les années 50, April et Frank Wheeler forment un couple à part, soucieux de vivre une vie différente avec des objectifs élevés. En emménageant dans leur belle maison, ils jurent qu'ils ne se laisseront pas envahir par la torpeur ambiante. Pourtant, les Wheeler finissent par vivre l'existence qu'ils redoutaient. Frank a un travail sans intérêt et April, femme au foyer, voit ses rêves d'évasion s'envoler.\n"]

# %% [markdown]
# ---
#
# ### Exercise 23:
# Create a new file `"report.txt"` and write the string `"Data analysis report"` to it.
#
# ```python
# # Exercise 23
# ```

# %%
with open('report.txt', 'r') as file:
    content = file.read()
    print(f"\nContent of report.txt:\n{content}")
# Out:
# Content of report.txt:
# A text report is a factual, objective presentation of information on a general topic, often summarizing the results of an investigation or study. It typically includes a title, general classification of the subject, and detailed descriptions, using the simple present tense and generic nouns. Key differences from descriptive texts are that a report text offers a broad overview rather than focusing on a single example and avoids subjective opinions.

# %% [markdown]
# ---
#
# ### Exercise 24:
# Replace the word `"error"` with `"issue"` in a file `"log.txt"`.
#
# ```python
# # Exercise 24
# ```

# %% [markdown]
# ---
#
# ### Exercise 25:
# Count the number of words in a text file `"document.txt"`.
#
# ```python
# # Exercise 25
# ```

# %% [markdown]
# ---
#
# ### Exercise 26:
# Write a Python script that reads a file `"essay.txt"` and prints the total number of lines, words, and characters.
#
# ```python
# # Exercise 26
# ```
#
# ---
#
# ### Exercise 27:
# Copy the contents of one file `"source.txt"` to another file `"destination.txt"`.
#
# ```python
# # Exercise 27
# ```
#
# ---
#
# ### Exercise 28:
# Write a Python function that takes a filename as input and returns the number of lines in the file.
#
# ```python
# # Exercise 28
# ```
#
# ---
#
# ### Exercise 29:
# Extract all the words from a text file `"article.txt"` that contain more than 5 characters.
#
# ```python
# # Exercise 29
# ```
#
# ---
#
# ### Exercise 30:
# Convert the contents of a file `"notes.txt"` to uppercase and save the result in another file `"uppercase_notes.txt"`.
#
# ```python
# # Exercise 30
# ```
#
# ---
#
# ### Exercise 31:
# Write a Python script that reads a file and removes all empty lines.
#
# ```python
# # Exercise 31
# ```
#
# ---
#
# ### Exercise 32:
# Open a file `"config.txt"` in both read and write mode.
#
# ```python
# # Exercise 32
# ```
#
# ---
#
# ### Exercise 33:
# Write a Python function that reads a file and prints the longest line in the file.
#
# ```python
# # Exercise 33
# ```
#
# ---
#
# ### Exercise 34:
# Write a Python script to count the frequency of each letter in a text file `"message.txt"`.
#
# ```python
# # Exercise 34
# ```
#
# ---
#
# ### Exercise 35:
# Write a Python script that reads a file and prints the total number of characters, excluding spaces.
#
# ```python
# # Exercise 35
# ```
#
# ---
#
# ### Exercise 36:
# Create a Python script to check whether a file is empty or not.
#
# ```python
# # Exercise 36
# ```
#
# ---
#
# ### Exercise 37:
# Write a Python function that reads a file and removes all punctuation marks from the text.
#
# ```python
# # Exercise 37
# ```
#
# ---
#
# ### Exercise 38:
# Create a Python function that writes a list of strings to a file, each string on a new line.
#
# ```python
# # Exercise 38
# ```
#
# ---
#
# ### Exercise 39:
# Write a Python script to count the number of lines that start with a specific letter (e.g., "A") in a text file.
#
# ```python
# # Exercise 39
# ```
#
# ---
#
# ### Exercise 40:
# Write a Python function that takes a string as input and writes it to a file `"output.txt"` in reverse order.
#
# ```python
# # Exercise 40
# ```
#
# ---
#
# ### Exercise 41:
# Write a Python script that reads a file and prints all the lines that contain the word `"Python"`.
#
# ```python
# # Exercise 41
# ```
#
# ---
#
# ### Exercise 42:
# Write a Python script that opens a file and removes all numeric digits from the file's content.
#
# ```python
# # Exercise 42
# ```
#
# ---
#
# ### Exercise 43:
# Write a Python script to find the most frequent word in a text file `"book.txt"`.
#
# ```python
# # Exercise 43
# ```
#
# ---
#
# ### Exercise 44:
# Write a Python script that reads a file and prints all the lines that contain exactly 5 words.
#
# ```python
# # Exercise 44
# ```
#
# ---
#
# ### Exercise 45:
# Write a Python script to read a file and print the first and last line of the file.
#
# ```python
# # Exercise 45
# ```
#
# ---
#
# ### Exercise 46:
# Write a Python script that checks if a file `"students.txt"` is writable.
#
# ```python
# # Exercise 46
# ```
#
# ---
#
# ### Exercise 47:
# Create a Python function that opens a file and returns the number of unique words in the file.
#
# ```python
# # Exercise 47
# ```
#
# ---
#
# ### Exercise 48:
# Write a Python script that reads a file and prints all lines in reverse order.
#
# ```python
# # Exercise 48
# ```
#
# ---
#
# ### Exercise 49:
# Write a Python function that reads a file and returns the most common letter in the text.
#
# ```python
# # Exercise 49
# ```
#
# ---
#
# ### Exercise 50:
# Write a Python script that reads a file and replaces every occurrence of `"Python"` with `"Java"`.
#
# ```python
# # Exercise 50
# ```
#
# ---
